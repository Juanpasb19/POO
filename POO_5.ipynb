# %%
def Hola( ): #Funcion para definir la palabra
    x = "Hola!"
    return x
Hola( )
'Hola!'
def Hi():
    print("Hi!")
Hi()
Hi!
# Podemos crear una función que haga la concatenación de dos listas

def conc(L,M): #Función para repetir o nombrar dos cosas
    x = L+M
    return x
conc(3,2)
5
L = [1,2]
M = [3,4]
conc(L,M)
[1, 2, 3, 4]
# Crear una definición que sume entrada dos listas

def suma_vectores(v, w):
    x = [v[i]+w[i] for i in range(0,3)] # Para darle instrucciones y el rango para sacar los vectores
    return x
suma_vectores( [1,2,3], [1,2,3] )
[2, 4, 6]
Clases
No tomen argumentos
Muestra enunciados usando el método de inicialización init.
El método para crear clases es class.
class Animal(): #Definición sobre como se tiene que portar un objeto o que es lo que tiene que hacer

    def _init_(self):
        print("creamos una clase")

    def adivina(self):
        print("Hola, soy un animal")

    def escribir(self):
        print("Estoy escribiendo")

type(Animal()) #Tipo de objeto
__main__.Animal
animal = Animal()
animal.adivina()
Hola, soy un animal
animal.escribir()
Estoy escribiendo
Herencia
Crear nuevas clases inherentes a métodos de la "clase base".

class Perro(Animal): # Clase madre

    def __init__(self):      # Inicia las definiciones y las clases de lo que queremos que nos diga
        Animal._init_(self)
        print("Creamos una clase Perro")

    def adivina(self):
        print("Soy Cleto")

    def wuaw(self):
        print("WUAU")
perro = Perro()
creamos una clase
Creamos una clase Perro
perro
<__main__.Perro at 0x7fc3aeaaed00>
print(animal.adivina())   # Imprime la información o el resultado
print(perro.adivina())
Hola, soy un animal
None
Soy Cleto
None
perro.wuaw()
WUAU
perro.adivina()
Soy Cleto
Ejemplo
class Fecha(): # Clases heredadas

    def _init_(self):
        print("creamos una clase que da la fecha")

    def fecha(self):
        return "2022-25-08"  # Imprime el resultado
f = Fecha()
f.fecha()
'2022-25-08'
class Tiempo(Fecha):  # Clases heredadas

    def _init_(self):
        Fecha._init_(self)
        print("Creamos una clase Tiempo")

    def hora(self):
        return "7:00"
t = Tiempo() # Valor de tiempo

t.hora()
'7:00'
Métodos objeto
_init_ inicializa la clase base. __init__ inicializa la clase base y sirve como constructor. Ojo: se ponen dos guiones abajo al principio y al final.

class Persona(): #Clase madre

    def __init__(self, nombre): # Definicion para nombrar
        self.nombre = nombre

    def greet(self):  # Le da un nombre específico o personalizado
        print("Hola, mi nombre es", self.nombre)
p = Persona("Aarón")
p.greet()
Hola, mi nombre es Aarón
class Complex(): # Clase Madre

    def __init__(self, real, imaginaria):
        self.r = real
        self.i = imaginaria
z = Complex(3.0,4.0)
z.r
3.0
z.i
4.0
class Perro(): # Clase madre

    animal = "perrito"

    def __init__(self, Raza, Color, Edad):
        self.Raza = Raza
        self.Color = Color
        self.Edad = Edad
Cleto = Perro("Pug", "beige", "viejito") #presenta conjunto de resultados de variables
print("Cleto detalles:")

print("Cleto es un", Cleto.animal) #conecta los variables con su resultado

print("La raza de Cleto es", Cleto.Raza)

print("El color de Cleto es", Cleto.Color)

print("La edad de Cleto es", Cleto.Edad)
Cleto detalles:
Cleto es un perrito
La raza de Cleto es Pug
El color de Cleto es beige
La edad de Cleto es viejito
Otro ejemplo
class Empleados():

    Conteo = 0 #empieza connteo de empleados con 0

    def __init__(self, nombre, salario):
        self.nombre = nombre
        self.salario = salario
        Empleados.Conteo += 1 #define que con cada empleado agregue 1

    def conteo(self): #print no es un argumento y no se necesita property
        print("Empleados %d" % Empleados.Conteo) #define variable de conteo


    def empleado(self):
        print("Nombre:", self.nombre, ",Salario:", self.salario) #define variable empleado y define sus caracter€isticas osea nombre y salario
emp1 = Empleados("Carlos", 10000)
emp1.empleado()
Nombre: Carlos ,Salario: 10000
emp2 = Empleados("Esteban", 30000)
emp2.empleado()
Nombre: Esteban ,Salario: 30000
Empleados.Conteo #conteo de empleados
2
emp1 = Empleados("Carlos", 10000)
emp2 = Empleados("Esteban", 30000) # cada vez que se corre el codigo agrega el numero de empleados definidos

print("Total de empleados %d" % Empleados.Conteo)
Total de empleados 12
Clases, herencias y polimorfismos
class Person:

    def __init__(self, last_name, first_name, age):
        self.__last_name = last_name
        self.__first_name = first_name
        self.__age = age

    @property
    def last_name(self):
        return self.__last_name #cuando hay un return (un argumento) se tiene que definir con el at @property

    @property
    def first_name(self):
        return self.__first_name

    @property
    def age(self):
        return self.__age
cesar = Person("Gal", "César", 25)
print(cesar.last_name)
print(cesar.first_name)
print(cesar.age)
Gal
César
25
class PrimeNumber:
    def __init__(self, number):
        self.number = number

    def is_prime(self): #para definir si es primo
        if self.number < 2:
            return False #el return es dentro del if y no cuenta como argumento en si mismo
        for i in range(2, int(self.number ** 0.5) + 1):
            if self.number % i == 0:
                return False
        return True

class PositivePrimeNumber(PrimeNumber): #si el numero es negativo imprime que el numero tiene que ser postiivo
    def __init__(self, number):
        if number <= 0:
            raise ValueError("El número debe ser positivo")
        super().__init__(number)

# Example usage:
num1 = PrimeNumber(7)
print(num1.is_prime())  # Output: True

num2 = PositivePrimeNumber(11)
print(num2.is_prime())  # Output: True
True
True
